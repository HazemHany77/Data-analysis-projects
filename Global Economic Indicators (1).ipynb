# %%
# !pip install country_converter
# Out:
# Requirement already satisfied: country_converter in /usr/local/lib/python3.12/dist-packages (1.3.2)
# Requirement already satisfied: pandas>=1.0 in /usr/local/lib/python3.12/dist-packages (from country_converter) (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->country_converter) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->country_converter) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->country_converter) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.0->country_converter) (2026.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0->country_converter) (1.17.0)
# Found existing installation: kaleido 0.2.1
# Uninstalling kaleido-0.2.1:
#   Successfully uninstalled kaleido-0.2.1
# Collecting kaleido==0.2.1
#   Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl.metadata (15 kB)
# Using cached kaleido-0.2.1-py2.py3-none-manylinux1_x86_64.whl (79.9 MB)
# Installing collected packages: kaleido
# Successfully installed kaleido-0.2.1

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import country_converter as coco
import plotly.express as px
import kagglehub
from IPython.display import Image, display

# %% [markdown]
# # Uploading and preparing data

# %%
# Download latest version
path = kagglehub.dataset_download("tanishksharma9905/global-economic-indicators-20102025")

print("Path to dataset files:", 'world_bank_data_2025.csv')
# Out:
# Using Colab cache for faster access to the 'global-economic-indicators-20102025' dataset.
# Path to dataset files: world_bank_data_2025.csv

# %%
file_path = path + '/world_bank_data_2025.csv'
data = pd.read_csv(file_path)

# %%
data.columns
# Out:
# Index(['country_name', 'country_id', 'year', 'Inflation (CPI %)',
#        'GDP (Current USD)', 'GDP per Capita (Current USD)',
#        'Unemployment Rate (%)', 'Interest Rate (Real, %)',
#        'Inflation (GDP Deflator, %)', 'GDP Growth (% Annual)',
#        'Current Account Balance (% GDP)', 'Government Expense (% of GDP)',
#        'Government Revenue (% of GDP)', 'Tax Revenue (% of GDP)',
#        'Gross National Income (USD)', 'Public Debt (% of GDP)'],
#       dtype='object')

# %% [markdown]
# # Data cleaning

# %%
data.info() # NO duplicated values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3472 entries, 0 to 3471
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country_name                     3472 non-null   object
#  1   country_id                       3472 non-null   object
#  2   year                             3472 non-null   int64
#  3   Inflation (CPI %)                2694 non-null   float64
#  4   GDP (Current USD)                2933 non-null   float64
#  5   GDP per Capita (Current USD)     2938 non-null   float64
#  6   Unemployment Rate (%)            2795 non-null   float64
#  7   Interest Rate (Real, %)          1735 non-null   float64
#  8   Inflation (GDP Deflator, %)      2904 non-null   float64
#  9   GDP Growth (% Annual)            2912 non-null   float64
#  10  Current Account Balance (% GDP)  2563 non-null   float64
#  11  Government Expense (% of GDP)    1820 non-null   float64
#  12  Government Revenue (% of GDP)    1829 non-null   float64
#  13  Tax Revenue (% of GDP)           1833 non-null   float64
#  14  Gross National Income (USD)      2796 non-null   float64
#  15  Public Debt (% of GDP)           852 non-null    float64
# dtypes: float64(13), int64(1), object(2)
# memory usage: 434.1+ KB

# %%
data.isna().sum()
# Out:
# country_name                          0
# country_id                            0
# year                                  0
# Inflation (CPI %)                   778
# GDP (Current USD)                   539
# GDP per Capita (Current USD)        534
# Unemployment Rate (%)               677
# Interest Rate (Real, %)            1737
# Inflation (GDP Deflator, %)         568
# GDP Growth (% Annual)               560
# Current Account Balance (% GDP)     909
# Government Expense (% of GDP)      1652
# Government Revenue (% of GDP)      1643
# Tax Revenue (% of GDP)             1639
# Gross National Income (USD)         676
# Public Debt (% of GDP)             2620
# dtype: int64

# %%
data.isna().sum().sum() # that is a lot of nulls
# Out:
# np.int64(14532)

# %%
data['country_id'].nunique()
# Out:
# 217

# %% [markdown]
# To handle the missing values, we will apply several approaches. Variables such as GDP and GDP growth will be derived from one another, while any remaining missing values will be estimated through interpolation. Variables such as GNI and GDP per capita will also be imputed using interpolation. For the other percentage-based variables, missing values will be filled using the median calculated across years and the additional classifications that will be created.

# %%
# Renaming columns
data.columns=data.columns.str.replace('GDP per Capita (Current USD)','per capita GDP')
data.columns=data.columns.str.replace('GDP (Current USD) ','GDP')
data.columns=data.columns.str.replace('Inflation (CPI %)','Inflation_CPI')

# %%
# Dropping these countries ever since their whole data is missing and other won't appear in the classification
data=data[data['country_id'] != 'gi']
data=data[data['country_id'] != 'vg']
data=data[data['country_id'] != 'kp']
data=data[data['country_id'] != 'mf']
data=data[data['country_id'] != 'jg']

# %%
# Classifying the countries by continent
cc = coco.CountryConverter()
continents=[]
for code in data['country_id']:
    continent=cc.convert(names=str(code).upper(), to='continent')
    continents.append(continent)
data['continent']=continents

# %%
data['continent'].unique()
# Out:
# array(['America', 'Asia', 'Africa', 'Europe', 'Oceania'], dtype=object)

# %%
# Classifying the countries by region
cc=coco.CountryConverter()
subregions=[]
for code in data['country_id']:
    subregion = cc.convert(names=str(code).upper(), to='UNregion')
    subregions.append(subregion)
data['subregion'] = subregions

# %%
# Adding the world bank GDP per capita classification
def percapitacall(per_capita_GDP):
    if per_capita_GDP <= 1135:
        return 'lower income'
    elif 1136 <  per_capita_GDP < 4495:
        return 'lower middle income'
    elif 4496 < per_capita_GDP < 13935:
        return 'upper middle income'
    else:
        return 'high income'
data['per capita class']=data['per capita GDP'].apply(percapitacall)

# %%
# rounding columns to 3 numbers to make it easier to read while not affecting the analysis

def roundcolumns(df,columns,decimals=3):
    df[columns]=df[columns].round(decimals)
    return df

cols= ['Inflation (GDP Deflator, %)',
    'Inflation_CPI',
    'Interest Rate (Real, %)',
    'GDP Growth (% Annual)',
    'Current Account Balance (% GDP)',
    'Government Expense (% of GDP)',
    'Government Revenue (% of GDP)',
    'Public Debt (% of GDP)',
    'Tax Revenue (% of GDP)',
    'per capita GDP']

data = roundcolumns(data,cols,3)

# %%
data=data.sort_values(['country_id','year'])
data
# Out:
#      country_name country_id  year  Inflation_CPI  GDP (Current USD)  \
# 64        Andorra         ad  2010            NaN       3.449926e+09
# 65        Andorra         ad  2011            NaN       3.629134e+09
# 66        Andorra         ad  2012            NaN       3.188653e+09
# 67        Andorra         ad  2013            NaN       3.193513e+09
# 68        Andorra         ad  2014            NaN       3.271686e+09
# ...           ...        ...   ...            ...                ...
# 3467     Zimbabwe         zw  2021         98.546       2.724052e+10
# 3468     Zimbabwe         zw  2022        104.705       3.278975e+10
# 3469     Zimbabwe         zw  2023            NaN       3.523137e+10
# 3470     Zimbabwe         zw  2024            NaN                NaN
# 3471     Zimbabwe         zw  2025            NaN                NaN
#
#       per capita GDP  Unemployment Rate (%)  Interest Rate (Real, %)  \
# 64         42746.831                    NaN                      NaN
# 65         46657.156                    NaN                      NaN
# 66         41500.544                    NaN                      NaN
# 67         42470.316                    NaN                      NaN
# 68         44369.660                    NaN                      NaN
# ...              ...                    ...                      ...
# 3467        1724.388                  9.540                  -31.796
# 3468        2040.552                 10.087                  -36.833
# 3469        2156.034                  8.759                  -73.540
# 3470             NaN                  8.554                      NaN
# 3471             NaN                    NaN                      NaN
#
#       Inflation (GDP Deflator, %)  GDP Growth (% Annual)  \
# 64                          0.374                 -1.975
# 65                          0.197                 -0.008
# 66                          0.175                 -4.974
# 67                          0.448                 -3.548
# 68                         -0.084                  2.504
# ...                           ...                    ...
# 3467                      113.295                  8.468
# 3468                      266.987                  6.139
# 3469                      921.536                  5.337
# 3470                          NaN                    NaN
# 3471                          NaN                    NaN
#
#       Current Account Balance (% GDP)  Government Expense (% of GDP)  \
# 64                                NaN                            NaN
# 65                                NaN                            NaN
# 66                                NaN                            NaN
# 67                                NaN                            NaN
# 68                                NaN                            NaN
# ...                               ...                            ...
# 3467                            1.278                            NaN
# 3468                            0.930                            NaN
# 3469                            0.380                            NaN
# 3470                              NaN                            NaN
# 3471                              NaN                            NaN
#
#       Government Revenue (% of GDP)  Tax Revenue (% of GDP)  \
# 64                              NaN                     NaN
# 65                              NaN                     NaN
# 66                              NaN                     NaN
# 67                              NaN                     NaN
# 68                              NaN                     NaN
# ...                             ...                     ...
# 3467                            NaN                     NaN
# 3468                            NaN                     NaN
# 3469                            NaN                     NaN
# 3470                            NaN                     NaN
# 3471                            NaN                     NaN
#
#       Gross National Income (USD)  Public Debt (% of GDP) continent  \
# 64                            NaN                     NaN    Europe
# 65                            NaN                     NaN    Europe
# 66                            NaN                     NaN    Europe
# 67                            NaN                     NaN    Europe
# 68                            NaN                     NaN    Europe
# ...                           ...                     ...       ...
# 3467                 2.662178e+10                     NaN    Africa
# 3468                 3.202694e+10                     NaN    Africa
# 3469                 3.479607e+10                     NaN    Africa
# 3470                          NaN                     NaN    Africa
# 3471                          NaN                     NaN    Africa
#
#             subregion     per capita class
# 64    Southern Europe          high income
# 65    Southern Europe          high income
# 66    Southern Europe          high income
# 67    Southern Europe          high income
# 68    Southern Europe          high income
# ...               ...                  ...
# 3467   Eastern Africa  lower middle income
# 3468   Eastern Africa  lower middle income
# 3469   Eastern Africa  lower middle income
# 3470   Eastern Africa          high income
# 3471   Eastern Africa          high income
#
# [3392 rows x 19 columns]

# %% [markdown]
# `GDP Growth (% Annual)`

# %%
# Calculating the growth through available GDP
data['GDP Growth (% Annual)']=(data.groupby('country_id')['GDP (Current USD)'].pct_change(fill_method=None)*100)

# %%
# Filling the rest with interpolate
data['GDP Growth (% Annual)'] = data.groupby('country_id')['GDP Growth (% Annual)'].transform(
    lambda x: x.interpolate(method='linear'))

# %%
data.pivot(index='country_name',columns='year',values="GDP Growth (% Annual)").head(30)
# Out:
# year                    2010       2011       2012       2013       2014  \
# country_name
# Afghanistan              NaN  12.287762  11.806908   1.201000   1.740815
# Albania                  NaN   8.081157  -4.428956   3.704517   3.537219
# Algeria                  NaN  22.806694   4.035964   1.126020   4.023150
# American Samoa           NaN  -0.523560  12.280702  -0.312500   0.783699
# Andorra                  NaN   5.194542 -12.137355   0.152421   2.447858
# Angola                   NaN  33.401491  14.547996   3.347205   2.741210
# Antigua and Barbuda      NaN  -1.303173   3.572079  -0.126703   4.029173
# Argentina                NaN  25.147263   2.984818   1.106769  -4.656575
# Armenia                  NaN   9.522666   4.705222   4.728586   4.388350
# Aruba                    NaN   7.509872  -0.858683   4.307165   2.309511
# Australia                NaN  21.741301  10.647829   1.912144  -6.902312
# Austria                  NaN  10.036983  -5.176362   4.875228   2.807329
# Azerbaijan               NaN  24.652571   5.651236   6.430280   1.455255
# Bahamas, The             NaN  -0.250699   6.454031  -3.027872   5.562823
# Bahrain                  NaN  11.597026   6.848555   5.818905   2.806354
# Bangladesh               NaN  11.565283   3.657070  12.518278  15.258542
# Barbados                 NaN   2.908685  -1.327665   1.705492   0.089875
# Belarus                  NaN   7.916000   6.352585  14.982926   4.349732
# Belgium                  NaN   9.477630  -5.459497   5.152873   2.650348
# Belize                   NaN   4.660022   4.507266   6.460145   5.190014
# Benin                    NaN  12.144043   4.189874  12.354751   6.124718
# Bermuda                  NaN  -4.850912   1.037545   1.372929  -0.800649
# Bhutan                   NaN  15.732399  -0.219516  -1.504534   7.479696
# Bolivia                  NaN  21.951662  13.025545  13.198847   7.621981
# Bosnia and Herzegovina   NaN   8.546173  -7.602874   5.528456   2.088249
# Botswana                 NaN  19.572024  -7.962461   2.619273   8.396661
# Brazil                   NaN  18.440398  -5.769091   0.307953  -0.678408
# Brunei Darussalam        NaN  35.147206   2.826765  -5.009833  -5.506480
# Bulgaria                 NaN  13.743073  -5.973472   2.880904   2.337707
# Burkina Faso             NaN  19.493080   3.979366   7.031958   3.709495
#
# year                         2015       2016       2017       2018       2019  \
# country_name
# Afghanistan             -6.649258  -5.318477   3.515478  -3.733892   4.133455
# Albania                -13.919518   4.165740   9.767362  18.124680   1.336813
# Algeria                -21.531864  -3.589460   5.043629   2.461325  -0.562733
# American Samoa           4.665630  -0.297177  -8.792846   4.411765   1.251956
# Andorra                -14.726487   3.825583   3.574923   7.274867  -1.965889
# Angola                 -33.442268 -41.697564  39.666217   7.817236 -10.764822
# Antigua and Barbuda      4.273619   3.612369   2.783075   8.515013   3.841173
# Argentina               13.001530  -6.257589  15.442346 -18.459176 -14.684125
# Armenia                 -9.097502  -0.068237   9.305043   8.071874   9.322165
# Aruba                    6.165059   0.699581   3.646352   5.942103   3.651032
# Australia               -7.966474 -10.690431   9.839415   7.711808  -2.457276
# Austria                -13.455504   3.725835   5.394834   9.075388  -2.120863
# Azerbaijan             -29.457221 -28.655458   7.921490  15.283480   2.253682
# Bahamas, The             6.358608   0.627147   4.185575   3.098057   3.173798
# Bahrain                 -6.468408   4.185870   9.798330   6.351772   2.221063
# Bangladesh              12.875489  35.910389  10.748603   9.406624   9.294451
# Barbados                -1.452093   0.807551   3.500043   2.040399   2.813040
# Belarus                -28.368380 -15.466054  14.671494   9.695463   7.294458
# Belgium                -14.301943   2.868875   5.616445   8.330888  -1.089595
# Belize                   2.562843   2.149974   1.165075   1.189163   4.144773
# Benin                  -14.275004   3.801359   7.449328  12.287786   0.906426
# Bermuda                  3.750444   3.687257   3.513161   1.171343   2.733028
# Bhutan                   4.726303   7.756090   9.919524  -0.309579   5.897331
# Bolivia                  0.012154   2.851280  10.510894   7.408975   1.508341
# Bosnia and Herzegovina -11.608468   4.343833   7.065796  11.773636  -0.007055
# Botswana               -12.536061  11.469346   6.779442   5.754600  -1.796830
# Brazil                 -26.621331  -0.361707  14.914655  -7.103466  -2.276849
# Brunei Darussalam      -24.374488 -11.832913   6.384956  11.862800  -0.719936
# Bulgaria               -11.102228   6.203766   9.905622  11.767911   3.533694
# Burkina Faso           -15.139169   8.461716   9.924075  12.639939   0.898343
#
# year                         2020       2021       2022       2023       2024  \
# country_name
# Afghanistan              6.151695 -28.542563   1.663734  18.871227  18.871227
# Albania                 -2.204967  18.308955   5.463795  23.820158  23.820158
# Algeria                -14.776334  12.954053  21.160391   9.744662   9.744662
# American Samoa          11.437403   4.022191  16.133333  16.133333  16.133333
# Andorra                 -8.371971  14.999869   1.683338  11.963949  11.963949
# Angola                 -31.589626  37.119566  56.979991 -18.750134 -18.750134
# Antigua and Barbuda    -18.231386  13.508000  16.633709   8.853076   8.853076
# Argentina              -13.850034  26.137669  30.052770   2.099465   2.099465
# Armenia                 -7.177995   9.786739  40.598278  23.431171  23.431171
# Aruba                  -26.913895  18.034457  11.944132  11.259253  11.259253
# Australia               -4.617554  17.187541   8.615622   2.200011   2.200011
# Austria                 -1.938230  10.605361  -1.809366   8.459899   8.459899
# Azerbaijan             -11.377939  28.417801  43.742597  -8.186145  -8.186145
# Bahamas, The           -23.493800  14.166215  15.546799   9.150909   9.150909
# Bahrain                -11.395647  13.959013  14.300088  -1.286476  -1.286476
# Bangladesh               6.476577  11.308698  10.536399  -4.936925  -4.936925
# Barbados               -10.710309   2.068314  18.616424   7.406221   7.406221
# Belarus                 -4.717221  13.527382   5.886626  -2.599515  -2.599515
# Belgium                 -1.310141  12.988537  -0.844656   8.651934   8.651934
# Belize                 -14.464263  18.488876  17.605503   7.733516   7.733516
# Benin                    8.754074  13.024518  -1.629937  13.069394  13.069394
# Bermuda                 -7.224632   5.800079   7.429699   4.007675   4.007675
# Bhutan                 -10.164890  12.662682   4.674395   4.674395   4.674395
# Bolivia                -10.430237  10.309266   8.914917   2.561143   2.561143
# Bosnia and Herzegovina  -1.252634  17.040786   3.641118  12.146565  12.146565
# Botswana               -10.556180  25.338113   8.378309  -4.556029  -4.556029
# Brazil                 -21.202342  13.179271  16.836380  11.360162  11.360162
# Brunei Darussalam      -10.865024  16.664421  19.098565  -9.311153  -9.311153
# Bulgaria                 3.038092  19.374641   7.373906  12.979293  12.979293
# Burkina Faso            10.554586  11.128376  -4.453849   7.993526   7.993526
#
# year                         2025
# country_name
# Afghanistan             18.871227
# Albania                 23.820158
# Algeria                  9.744662
# American Samoa          16.133333
# Andorra                 11.963949
# Angola                 -18.750134
# Antigua and Barbuda      8.853076
# Argentina                2.099465
# Armenia                 23.431171
# Aruba                   11.259253
# Australia                2.200011
# Austria                  8.459899
# Azerbaijan              -8.186145
# Bahamas, The             9.150909
# Bahrain                 -1.286476
# Bangladesh              -4.936925
# Barbados                 7.406221
# Belarus                 -2.599515
# Belgium                  8.651934
# Belize                   7.733516
# Benin                   13.069394
# Bermuda                  4.007675
# Bhutan                   4.674395
# Bolivia                  2.561143
# Bosnia and Herzegovina  12.146565
# Botswana                -4.556029
# Brazil                  11.360162
# Brunei Darussalam       -9.311153
# Bulgaria                12.979293
# Burkina Faso             7.993526

# %%
data['GDP Growth (% Annual)'].isna().sum()
# Out:
# np.int64(212)

# %% [markdown]
# We'll notice that the data missing is from 2010 for all countries, so we can't extract growth from any previous year, but we'll update it with the next value

# %%
data['GDP Growth (% Annual)'] = data['GDP Growth (% Annual)'].bfill()

# %%
data['GDP Growth (% Annual)'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# `GDP (Current USD)`

# %%
# Calculating the GDP from the GDP growth
data = data.sort_values(['country_id', 'year'])
data['GDP (Current USD)']=data['GDP (Current USD)'].fillna(data.groupby('country_id')['GDP (Current USD)'].shift(1)*(1+data['GDP Growth (% Annual)']/100))

# %%
# filling the rest with interpolate
data['GDP (Current USD)'] = data.groupby('country_id')['GDP (Current USD)'].transform(lambda x: x.interpolate(method='linear'))

# %%
data['GDP (Current USD)'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# `per capita GDP`

# %% [markdown]
# The GDP and GDP growth have been solved. Now we are heading towards the GDP per capita. GDP per capita (yearly income) is calculated by dividing GDP by the population. But ever since we don't have it, we also use the interpolation approach.

# %%
# Filling the missing
data['per capita GDP'] = data.groupby('country_id')['per capita GDP'].transform(
    lambda x: x.interpolate(method='linear'))

# %%
data['per capita GDP'].isna().sum()
# Out:
# np.int64(0)

# %% [markdown]
# `GNI (Gross National income)`

# %%
# Filling with interplolate
data['Gross National Income (USD)'] = data.groupby('country_id')['Gross National Income (USD)'].transform(lambda x: x.interpolate(method='linear'))

# %% [markdown]
# Hence, there are still missing values; it means there are countries that their whole GNI is missing. We will fill the rest with median across the year and the classes we created

# %%
data['Gross National Income (USD)'].isna().sum()
# Out:
# np.int64(133)

# %%
def GNIfill(df,columns,glist):
    for groups in glist:
        df[columns]=df[columns].fillna(df.groupby(groups)[columns].transform('median'))
    return df
glist=[['year', 'subregion', 'per capita class'],
    ['year', 'subregion'],
       ['subregion','per capita class'],
       ['subregion']]

data = GNIfill(data,'Gross National Income (USD)',glist)

# %%
data['Gross National Income (USD)'].isna().sum()
# Out:
# np.int64(0)

# %%
data.isnull().sum().sum()
# Out:
# np.int64(11547)

# %% [markdown]
# `Public debt and real interest rate`

# %% [markdown]
# Now we head to the indicators for which we will need classification to calculate the median across these classifications. But first we will drop the Public Debt (% of GDP) and the real interest rate columns, because more than 50% of their values are missing, and imputing such a large share would likely reduce the reliability of the dataset.

# %%
# Dropping the GDP
data=data.drop(columns=['Public Debt (% of GDP)','Interest Rate (Real, %)'])

# %%
data.isna().sum().sum()
# Out:
# np.int64(7350)

# %% [markdown]
#
#
# *   `Inflation by CPI`
# *   `Unemployment rate`
# *   `Infaltion GDP dflator`
# *   `Current acount balance`
# *   `Government expences`
# *   `Government revenue`
# *   `Tax revenue`

# %%
def INFCPIfill(df,columns,glist):
    for groups in glist:
        df[columns]=df[columns].fillna(df.groupby(groups)[columns].transform('median'))
    return df
glist=[['year', 'subregion', 'per capita class'],
    ['year', 'subregion'],
       ['subregion','per capita class'],
       ['subregion']]

data = INFCPIfill(data,'Inflation_CPI',glist)

def UNRfill(df,columns,glist):
    for groups in glist:
        df[columns]=df[columns].fillna(df.groupby(groups)[columns].transform('median'))
    return df
glist=[['year', 'subregion', 'per capita class'],
    ['year', 'subregion'],
       ['subregion','per capita class'],
       ['subregion']]

data = UNRfill(data,'Unemployment Rate (%)',glist)


def IGDfill(df,columns,glist):
    for groups in glist:
        df[columns]=df[columns].fillna(df.groupby(groups)[columns].transform('median'))
    return df
glist=[['year', 'subregion', 'per capita class'],
    ['year', 'subregion'],
       ['subregion','per capita class'],
       ['subregion']]

data = IGDfill(data,'Inflation (GDP Deflator, %)',glist)

def CABfill(df,columns,glist):
    for groups in glist:
        df[columns]=df[columns].fillna(df.groupby(groups)[columns].transform('median'))
    return df
glist=[['year', 'subregion', 'per capita class'],
    ['year', 'subregion'],
       ['subregion','per capita class'],
       ['subregion']]

data = CABfill(data,'Current Account Balance (% GDP)',glist)

def GEfill(df,columns,glist):
    for groups in glist:
        df[columns]=df[columns].fillna(df.groupby(groups)[columns].transform('median'))
    return df
glist=[['year', 'subregion', 'per capita class'],
    ['year', 'subregion'],
       ['subregion','per capita class'],
       ['subregion']]

data = GEfill(data,'Government Expense (% of GDP)',glist)

def GRfill(df,columns,glist):
    for groups in glist:
        df[columns]=df[columns].fillna(df.groupby(groups)[columns].transform('median'))
    return df
glist=[['year', 'subregion', 'per capita class'],
    ['year', 'subregion'],
       ['subregion','per capita class'],
       ['subregion']]

data = GRfill(data,'Government Revenue (% of GDP)',glist)

def TRfill(df,columns,glist):
    for groups in glist:
        df[columns]=df[columns].fillna(df.groupby(groups)[columns].transform('median'))
    return df
glist=[['year', 'subregion', 'per capita class'],
    ['year', 'subregion'],
       ['subregion','per capita class'],
       ['subregion']]

data = TRfill(data,'Tax Revenue (% of GDP)',glist)

# %%
data.isna().sum()
# Out:
# country_name                       0
# country_id                         0
# year                               0
# Inflation_CPI                      0
# GDP (Current USD)                  0
# per capita GDP                     0
# Unemployment Rate (%)              0
# Inflation (GDP Deflator, %)        0
# GDP Growth (% Annual)              0
# Current Account Balance (% GDP)    0
# Government Expense (% of GDP)      0
# Government Revenue (% of GDP)      0
# Tax Revenue (% of GDP)             0
# Gross National Income (USD)        0
# continent                          0
# subregion                          0
# per capita class                   0
# dtype: int64

# %% [markdown]
# # EDA

# %%
# Adding the fiscal balance will help us in the analysis
data['fiscal balance % GDP']=data['Government Revenue (% of GDP)']-data['Government Expense (% of GDP)']

# %% [markdown]
# Now we can see which country its balance run a deficit or surplice

# %%
data
# Out:
#      country_name country_id  year  Inflation_CPI  GDP (Current USD)  \
# 64        Andorra         ad  2010         1.8000       3.449926e+09
# 65        Andorra         ad  2011         2.9315       3.629134e+09
# 66        Andorra         ad  2012         2.5970       3.188653e+09
# 67        Andorra         ad  2013         1.3145       3.193513e+09
# 68        Andorra         ad  2014         0.0240       3.271686e+09
# ...           ...        ...   ...            ...                ...
# 3467     Zimbabwe         zw  2021        98.5460       2.724052e+10
# 3468     Zimbabwe         zw  2022       104.7050       3.278975e+10
# 3469     Zimbabwe         zw  2023         7.6710       3.523137e+10
# 3470     Zimbabwe         zw  2024         3.7130       3.785479e+10
# 3471     Zimbabwe         zw  2025         3.7130       3.785479e+10
#
#       per capita GDP  Unemployment Rate (%)  Inflation (GDP Deflator, %)  \
# 64         42746.831                  9.567                        0.374
# 65         46657.156                 12.682                        0.197
# 66         41500.544                 13.093                        0.175
# 67         42470.316                 16.188                        0.448
# 68         44369.660                 13.897                       -0.084
# ...              ...                    ...                          ...
# 3467        1724.388                  9.540                      113.295
# 3468        2040.552                 10.087                      266.987
# 3469        2156.034                  8.759                      921.536
# 3470        2156.034                  8.554                        2.332
# 3471        2156.034                  5.586                        2.332
#
#       GDP Growth (% Annual)  Current Account Balance (% GDP)  \
# 64                 5.194542                          -4.1365
# 65                 5.194542                          -2.6870
# 66               -12.137355                          -0.0800
# 67                 0.152421                           1.5400
# 68                 2.447858                           1.7100
# ...                     ...                              ...
# 3467               1.386704                           1.2780
# 3468              20.371262                           0.9300
# 3469               7.446278                           0.3800
# 3470               7.446278                          -6.8830
# 3471               7.446278                          -6.8830
#
#       Government Expense (% of GDP)  Government Revenue (% of GDP)  \
# 64                          42.6930                        37.3980
# 65                          41.9230                        38.1535
# 66                          44.3630                        39.7540
# 67                          44.6645                        39.4400
# 68                          44.5970                        39.1635
# ...                             ...                            ...
# 3467                        19.3585                        14.9880
# 3468                        20.9550                        15.9400
# 3469                        17.0300                        13.4110
# 3470                        17.6260                        15.9400
# 3471                        17.6260                        15.9400
#
#       Tax Revenue (% of GDP)  Gross National Income (USD) continent  \
# 64                   20.4350                 2.605446e+11    Europe
# 65                   21.5275                 2.411463e+11    Europe
# 66                   21.7020                 2.275801e+11    Europe
# 67                   22.3850                 2.234069e+11    Europe
# 68                   22.4545                 2.251984e+11    Europe
# ...                      ...                          ...       ...
# 3467                 12.2055                 2.662178e+10    Africa
# 3468                 13.1960                 3.202694e+10    Africa
# 3469                 11.4910                 3.479607e+10    Africa
# 3470                 13.4510                 3.479607e+10    Africa
# 3471                 13.4510                 3.479607e+10    Africa
#
#             subregion     per capita class  fiscal balance % GDP
# 64    Southern Europe          high income               -5.2950
# 65    Southern Europe          high income               -3.7695
# 66    Southern Europe          high income               -4.6090
# 67    Southern Europe          high income               -5.2245
# 68    Southern Europe          high income               -5.4335
# ...               ...                  ...                   ...
# 3467   Eastern Africa  lower middle income               -4.3705
# 3468   Eastern Africa  lower middle income               -5.0150
# 3469   Eastern Africa  lower middle income               -3.6190
# 3470   Eastern Africa          high income               -1.6860
# 3471   Eastern Africa          high income               -1.6860
#
# [3392 rows x 18 columns]

# %%
data[data['Unemployment Rate (%)']==data['Unemployment Rate (%)'].max()]
# Out:
#      country_name country_id  year  Inflation_CPI  GDP (Current USD)  \
# 2940     Eswatini         sz  2022          6.081       4.695373e+09
#
#       per capita GDP  Unemployment Rate (%)  Inflation (GDP Deflator, %)  \
# 2940        3852.086                 35.359                        9.766
#
#       GDP Growth (% Annual)  Current Account Balance (% GDP)  \
# 2940              -0.892818                           -3.002
#
#       Government Expense (% of GDP)  Government Revenue (% of GDP)  \
# 2940                         35.724                         31.295
#
#       Tax Revenue (% of GDP)  Gross National Income (USD) continent  \
# 2940                  27.172                 4.318606e+09    Africa
#
#             subregion     per capita class  fiscal balance % GDP
# 2940  Southern Africa  lower middle income                -4.429

# %%
data.describe()
# Out:
#               year  Inflation_CPI  GDP (Current USD)  per capita GDP  \
# count  3392.000000    3392.000000       3.392000e+03     3392.000000
# mean   2017.500000       5.804594       4.099073e+11    18685.409368
# std       4.610452      18.049789       1.841578e+12    27958.398118
# min    2010.000000      -6.687000       3.210541e+07      193.007000
# 25%    2013.750000       1.496500       6.334383e+09     2263.938000
# 50%    2017.500000       3.049000       2.695395e+10     6875.172500
# 75%    2021.250000       5.931250       1.927618e+11    23746.980000
# max    2025.000000     557.202000       2.954746e+13   256580.515000
#
#        Unemployment Rate (%)  Inflation (GDP Deflator, %)  \
# count            3392.000000                  3392.000000
# mean                7.834836                     6.210164
# std                 5.587504                    24.105657
# min                 0.100000                   -28.760000
# 25%                 3.982000                     1.350750
# 50%                 6.090500                     2.973000
# 75%                10.413750                     6.423250
# max                35.359000                   921.536000
#
#        GDP Growth (% Annual)  Current Account Balance (% GDP)  \
# count            3392.000000                      3392.000000
# mean                5.475548                        -2.426405
# std                12.433930                        12.986001
# min               -53.989705                       -60.878000
# 25%                -0.220110                        -7.247750
# 50%                 5.462951                        -2.758000
# 75%                11.121794                         1.744000
# max               148.554483                       235.751000
#
#        Government Expense (% of GDP)  Government Revenue (% of GDP)  \
# count                    3392.000000                    3392.000000
# mean                       26.400663                      25.452060
# std                        12.200087                      15.141315
# min                         0.000000                       0.000000
# 25%                        17.387500                      16.949000
# 50%                        25.417000                      23.878000
# 75%                        33.197250                      30.668000
# max                       103.726000                     344.999000
#
#        Tax Revenue (% of GDP)  Gross National Income (USD)  \
# count             3392.000000                 3.392000e+03
# mean                16.530660                 4.172036e+11
# std                  6.907902                 1.832113e+12
# min                  0.000000                 5.107533e+07
# 25%                 12.710500                 6.609541e+09
# 50%                 16.222000                 2.838816e+10
# 75%                 20.489500                 2.062809e+11
# max                147.640000                 2.757614e+13
#
#        fiscal balance % GDP
# count           3392.000000
# mean              -0.948603
# std               10.405521
# min              -47.975000
# 25%               -3.525500
# 50%               -1.363500
# 75%                1.020000
# max              274.392000

# %% [markdown]
# As we can see in the data, most variable their mean doesn't equal the median, inidcating extrem skewness and sure the presence of  outliers. Outliers means that we have devolping, emerging and devolped economics within the data.

# %%
data.describe(include='O')
# Out:
#        country_name country_id continent  subregion per capita class
# count          3392       3392      3392       3392             3392
# unique          212        212         5         22                4
# top         Andorra         ad    Africa  Caribbean      high income
# freq             16         16       864        320             1492

# %% [markdown]
# As noted, most frequent countries are from Africa

# %%
data[data['Tax Revenue (% of GDP)'] == data['Tax Revenue (% of GDP)'].max()]
# Out:
#      country_name country_id  year  Inflation_CPI  GDP (Current USD)  \
# 3090  Timor-Leste         tl  2012           11.8       1.160555e+09
#
#       per capita GDP  Unemployment Rate (%)  Inflation (GDP Deflator, %)  \
# 3090        1022.619                  3.468                         6.16
#
#       GDP Growth (% Annual)  Current Account Balance (% GDP)  \
# 3090              11.320526                          235.751
#
#       Government Expense (% of GDP)  Government Revenue (% of GDP)  \
# 3090                          78.15                        337.757
#
#       Tax Revenue (% of GDP)  Gross National Income (USD) continent  \
# 3090                  147.64                 4.318282e+09      Asia
#
#                subregion per capita class  fiscal balance % GDP
# 3090  South-eastern Asia     lower income               259.607

# %% [markdown]
# `Global GDP`

# %%
df_2025 = data[data['year'] == 2025]
fig = px.choropleth(df_2025, locations="country_name",
                    color="GDP (Current USD)",
                    locationmode='country names',
                    hover_name="country_name",
                    title="Gross Domistic Product (GDP) in 2025",
                    color_discrete_sequence=px.colors.sequential.Inferno)

fig.update_layout(width=1000,height=800,margin=dict(l=80, r=80, t=80, b=80))
fig.show()
fig.write_html("fig1_chart.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="72e95342-bc81-43bb-9fd8-a4bb3f78adfc" class="plotly-graph-div" style="height:800px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("72e95342-bc81-43bb-9fd8-a4bb3f78adfc")) {                    Plotly.newPlot(                        "72e95342-bc81-43bb-9fd8-a4bb3f78adfc",                        [{"coloraxis":"coloraxis","geo":"geo","hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{location}\u003cbr\u003eGDP (Current USD)=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Andorra","United Arab Emirates","Afghanistan","Antigua and Barbuda","Albania","Armenia","Angola","Argentina","American Samoa","Austria","Australia","Aruba","Azerbaijan","Bosnia and Herzegovina","Barbados","Bangladesh","Belgium","Burkina Faso","Bulgaria","Bahrain","Burundi","Benin","Bermuda","Brunei Darussalam","Bolivia","Brazil","Bahamas, The","Bhutan","Botswana","Belarus","Belize","Canada","Congo, Dem. Rep.","Central African Republic","Congo, Rep.","Switzerland","Cote d'Ivoire","Chile","Cameroon","China","Colombia","Costa Rica","Cuba","Cabo Verde","Curacao","Cyprus","Czechia","Germany","Djibouti","Denmark","Dominica","Dominican Republic","Algeria","Ecuador","Estonia","Egypt, Arab Rep.","Eritrea","Spain","Ethiopia","Finland","Fiji","Micronesia, Fed. Sts.","Faroe Islands","France","Gabon","United Kingdom","Grenada","Georgia","Ghana","Greenland","Gambia, The","Guinea","Equatorial Guinea","Greece","Guatemala","Guam","Guinea-Bissau","Guyana","Hong Kong SAR, China","Honduras","Croatia","Haiti","Hungary","Indonesia","Ireland","Israel","Isle of Man","India","Iraq","Iran, Islamic Rep.","Iceland","Italy","Jamaica","Jordan","Japan","Kenya","Kyrgyz Republic","Cambodia","Kiribati","Comoros","St. Kitts and Nevis","Korea, Rep.","Kuwait","Cayman Islands","Kazakhstan","Lao PDR","Lebanon","St. Lucia","Liechtenstein","Sri Lanka","Liberia","Lesotho","Lithuania","Luxembourg","Latvia","Libya","Morocco","Monaco","Moldova","Montenegro","Madagascar","Marshall Islands","North Macedonia","Mali","Myanmar","Mongolia","Macao SAR, China","Northern Mariana Islands","Mauritania","Malta","Mauritius","Maldives","Malawi","Mexico","Malaysia","Mozambique","Namibia","New Caledonia","Niger","Nigeria","Nicaragua","Netherlands","Norway","Nepal","Nauru","New Zealand","Oman","Panama","Peru","French Polynesia","Papua New Guinea","Philippines","Pakistan","Poland","Puerto Rico","West Bank and Gaza","Portugal","Palau","Paraguay","Qatar","Romania","Serbia","Russian Federation","Rwanda","Saudi Arabia","Solomon Islands","Seychelles","Sudan","Sweden","Singapore","Slovenia","Slovak Republic","Sierra Leone","San Marino","Senegal","Somalia","Suriname","South Sudan","Sao Tome and Principe","El Salvador","Sint Maarten (Dutch part)","Syrian Arab Republic","Eswatini","Turks and Caicos Islands","Chad","Togo","Thailand","Tajikistan","Timor-Leste","Turkmenistan","Tunisia","Tonga","Turkiye","Trinidad and Tobago","Tuvalu","Tanzania","Ukraine","Uganda","United States","Uruguay","Uzbekistan","St. Vincent and the Grenadines","Venezuela, RB","Virgin Islands (U.S.)","Viet Nam","Vanuatu","Samoa","Kosovo","Yemen, Rep.","South Africa","Zambia","Zimbabwe"],"locationmode":"country names","locations":["Andorra","United Arab Emirates","Afghanistan","Antigua and Barbuda","Albania","Armenia","Angola","Argentina","American Samoa","Austria","Australia","Aruba","Azerbaijan","Bosnia and Herzegovina","Barbados","Bangladesh","Belgium","Burkina Faso","Bulgaria","Bahrain","Burundi","Benin","Bermuda","Brunei Darussalam","Bolivia","Brazil","Bahamas, The","Bhutan","Botswana","Belarus","Belize","Canada","Congo, Dem. Rep.","Central African Republic","Congo, Rep.","Switzerland","Cote d'Ivoire","Chile","Cameroon","China","Co ...

# %%
GDP_gr= data[data['year'] ==2025].groupby('country_name')['GDP (Current USD)'].sum().round(2).sort_values(ascending=False).head(10)
print(f'Top 10 biggest economies in 2025:\n{GDP_gr}')
print()

# Visualization

fig = px.bar(GDP_gr,x=GDP_gr.index,y=GDP_gr.values,color=GDP_gr.index,color_discrete_sequence=px.colors.sequential.Inferno,
    title='Top 10 biggest economies in the world',
    hover_name=GDP_gr.index,hover_data=['GDP (Current USD)'])

fig.update_layout( width=1000,
    height=600,
    xaxis_title='Country',
    yaxis_title='GDP (Current USD)')


fig.show()

fig.write_html("fig2_chart.html")
# Out:
# Top 10 biggest economies in 2025:
# country_name
# United States     2.954746e+13
# China             1.770821e+13
# Germany           4.919304e+12
# Japan             4.153212e+12
# India             3.795300e+12
# United Kingdom    3.670527e+12
# France            3.330712e+12
# Italy             2.517518e+12
# Brazil            2.420598e+12
# Mexico            2.185961e+12
# Name: GDP (Current USD), dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3a055204-4706-48aa-bd13-b926e14e77c5" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3a055204-4706-48aa-bd13-b926e14e77c5")) {                    Plotly.newPlot(                        "3a055204-4706-48aa-bd13-b926e14e77c5",                        [{"alignmentgroup":"True","customdata":[[29547462953866.92]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP (Current USD)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["United States"],"legendgroup":"United States","marker":{"color":"#000004","pattern":{"shape":""}},"name":"United States","offsetgroup":"United States","orientation":"v","showlegend":true,"textposition":"auto","x":["United States"],"xaxis":"x","y":[29547462953866.92],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[17708206671879.64]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP (Current USD)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["China"],"legendgroup":"China","marker":{"color":"#1b0c41","pattern":{"shape":""}},"name":"China","offsetgroup":"China","orientation":"v","showlegend":true,"textposition":"auto","x":["China"],"xaxis":"x","y":[17708206671879.64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4919303905276.11]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP (Current USD)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Germany"],"legendgroup":"Germany","marker":{"color":"#4a0c6b","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["Germany"],"xaxis":"x","y":[4919303905276.11],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4153212069379.33]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP (Current USD)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Japan"],"legendgroup":"Japan","marker":{"color":"#781c6d","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["Japan"],"xaxis":"x","y":[4153212069379.33],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3795299515210.51]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP (Current USD)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["India"],"legendgroup":"India","marker":{"color":"#a52c60","pattern":{"shape":""}},"name":"India","offsetgroup":"India","orientation":"v","showlegend":true,"textposition":"auto","x":["India"],"xaxis":"x","y":[3795299515210.51],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3670527103208.64]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP (Current USD)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["United Kingdom"],"legendgroup":"United Kingdom","marker":{"color":"#cf4446","pattern":{"shape":""}},"name":"United Kingdom","offsetgroup":"United Kingdom","orientation":"v","showlegend":true,"textposition":"auto","x":["United Kingdom"],"xaxis":"x","y":[3670527103208.64],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[3330711591047.55]],"hovertemplate":"\u003cb\u003e ...

# %% [markdown]
# US and China control the global economy

# %% [markdown]
# `GDP trend over the years`

# %%
GDPy_gr=data.groupby('year')['GDP (Current USD)'].sum()
print(f'Gross National Product (GDP) over the years: \n{GDPy_gr}')
print()

# Visualization

fig = px.line(GDPy_gr,x=GDPy_gr.index,y=GDPy_gr.values,markers=True,
              labels={'x': 'Year', 'y': 'GDP (Current USD)'},title='GDP over the years')

fig.update_layout(width=1000,
    height=600)

fig.update_traces(marker=dict(color='navy',size=8),
    line=dict(color='black',width=2))

fig.show()

fig.write_html("fig3_chart.html")
# Out:
# Gross National Product (GDP) over the years:
# year
# 2010    6.614079e+13
# 2011    7.356971e+13
# 2012    7.518291e+13
# 2013    7.733227e+13
# 2014    7.945572e+13
# 2015    7.527581e+13
# 2016    7.650106e+13
# 2017    8.144451e+13
# 2018    8.657920e+13
# 2019    8.783154e+13
# 2020    8.539378e+13
# 2021    9.732236e+13
# 2022    1.012343e+14
# 2023    1.056338e+14
# 2024    1.107538e+14
# 2025    1.107538e+14
# Name: GDP (Current USD), dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b9810baf-b9c5-4731-8461-2629f26936b2" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9810baf-b9c5-4731-8461-2629f26936b2")) {                    Plotly.newPlot(                        "b9810baf-b9c5-4731-8461-2629f26936b2",                        [{"hovertemplate":"year=%{x}\u003cbr\u003eGDP (Current USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"black","dash":"solid","width":2},"marker":{"symbol":"circle","color":"navy","size":8},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[66140790741762.73,73569714117724.44,75182906878180.62,77332266935607.16,79455717153611.22,75275812554437.98,76501061601049.27,81444507034245.36,86579199732742.78,87831536182493.27,85393777226278.33,97322359841363.3,101234289385453.83,105633793813372.58,110753839474932.61,110753839474932.61],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"ty ...

# %% [markdown]
# `GDP world contribution`

# %%
GDPyc_gr=data.groupby('continent')['GDP (Current USD)'].sum()
print(f'Gross National Product per continent:{GDPyc_gr}')
print()

# Visualization

fig = px.pie(data,values=GDPyc_gr.values,names=GDPyc_gr.index, title="Gross National Product per continent",
             color_discrete_sequence=px.colors.sequential.Inferno)
fig.update_layout( width=500,
    height=500)


fig.show()

fig.write_html("fig4_chart.html")
# Out:
# Gross National Product per continent:continent
# Africa     4.129734e+13
# America    4.694091e+14
# Asia       4.898290e+14
# Europe     3.619142e+14
# Oceania    2.795576e+13
# Name: GDP (Current USD), dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7d97a73a-ebdb-42f0-bd36-c24178540872" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7d97a73a-ebdb-42f0-bd36-c24178540872")) {                    Plotly.newPlot(                        "7d97a73a-ebdb-42f0-bd36-c24178540872",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Africa","America","Asia","Europe","Oceania"],"legendgroup":"","name":"","showlegend":true,"values":[41297335515235.39,469409129999801.8,489829035446710.8,361914153969006.44,27955757217433.61],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatter ...

# %% [markdown]
# `GDP per capita`

# %%
per_gr=data.groupby('country_name')['per capita GDP'].median().sort_values(ascending=False).head(10)
print(f'Top 10 economies with highest per capita GDP: \n{per_gr}')
print()

# Visualization

fig = px.bar(per_gr,x=per_gr.index,y=per_gr.values,color=per_gr.index,color_discrete_sequence=px.colors.sequential.Inferno,
    title='Top 10 richest countries in the world',
    hover_name=per_gr.index,hover_data=['per capita GDP'])

fig.update_layout(width=1000,
    height=600,
    xaxis_title='Country',
    yaxis_title='per capita GDP')

fig.show()

fig.write_html("fig5_chart.html")
# Out:
# Top 10 economies with highest per capita GDP:
# country_name
# Monaco            186619.4900
# Liechtenstein     171685.3500
# Luxembourg        117965.2135
# Bermuda           110543.3910
# Norway             87925.0940
# Switzerland        86601.0575
# Isle of Man        85940.5355
# Cayman Islands     81196.3710
# Qatar              78791.6010
# Ireland            76873.8205
# Name: per capita GDP, dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e626a5c1-f28b-4320-ab88-c9da80d2f115" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e626a5c1-f28b-4320-ab88-c9da80d2f115")) {                    Plotly.newPlot(                        "e626a5c1-f28b-4320-ab88-c9da80d2f115",                        [{"alignmentgroup":"True","customdata":[[186619.49]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eper capita GDP=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Monaco"],"legendgroup":"Monaco","marker":{"color":"#000004","pattern":{"shape":""}},"name":"Monaco","offsetgroup":"Monaco","orientation":"v","showlegend":true,"textposition":"auto","x":["Monaco"],"xaxis":"x","y":[186619.49],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[171685.35]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eper capita GDP=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Liechtenstein"],"legendgroup":"Liechtenstein","marker":{"color":"#1b0c41","pattern":{"shape":""}},"name":"Liechtenstein","offsetgroup":"Liechtenstein","orientation":"v","showlegend":true,"textposition":"auto","x":["Liechtenstein"],"xaxis":"x","y":[171685.35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[117965.2135]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eper capita GDP=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Luxembourg"],"legendgroup":"Luxembourg","marker":{"color":"#4a0c6b","pattern":{"shape":""}},"name":"Luxembourg","offsetgroup":"Luxembourg","orientation":"v","showlegend":true,"textposition":"auto","x":["Luxembourg"],"xaxis":"x","y":[117965.2135],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[110543.391]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eper capita GDP=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Bermuda"],"legendgroup":"Bermuda","marker":{"color":"#781c6d","pattern":{"shape":""}},"name":"Bermuda","offsetgroup":"Bermuda","orientation":"v","showlegend":true,"textposition":"auto","x":["Bermuda"],"xaxis":"x","y":[110543.391],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[87925.094]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eper capita GDP=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Norway"],"legendgroup":"Norway","marker":{"color":"#a52c60","pattern":{"shape":""}},"name":"Norway","offsetgroup":"Norway","orientation":"v","showlegend":true,"textposition":"auto","x":["Norway"],"xaxis":"x","y":[87925.094],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[86601.0575]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eper capita GDP=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Switzerland"],"legendgroup":"Switzerland","marker":{"color":"#cf4446","pattern":{"shape":""}},"name":"Switzerland","offsetgroup":"Switzerland","orientation":"v","showlegend":true,"textposition":"auto","x":["Switzerland"],"xaxis":"x","y":[86601.0575],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[85940.5355]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr ...

# %% [markdown]
# Monaco, Liechtenstein and Luxembourg are the richest countries in the world according to the per capita GDP

# %%
pery_gr = data.groupby('year')['per capita GDP'].median()
print(f'per capita GDP over the years: \n{pery_gr}')
print()
# Visualization

fig = px.line(pery_gr,x=pery_gr.index,y=pery_gr.values,markers=True
              ,title='GDP per capita trend over the years')

fig.update_layout(width=1000,
    height=600,xaxis_title='Country',
    yaxis_title='per capita GDP')

fig.update_traces(marker=dict(color='purple',size=8),
    line=dict(color='black',width=2))


fig.show()

fig.write_html("fig6_chart.html")
# Out:
# per capita GDP over the years:
# year
# 2010    5664.0900
# 2011    6504.2820
# 2012    6552.8895
# 2013    6924.3750
# 2014    7134.5345
# 2015    6147.8500
# 2016    5971.1065
# 2017    6513.7845
# 2018    6946.3345
# 2019    6820.9585
# 2020    6433.0895
# 2021    7054.6355
# 2022    7630.9160
# 2023    7979.7980
# 2024    7979.7980
# 2025    7979.7980
# Name: per capita GDP, dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="4c5c909f-8e84-4edb-a6b7-ae477a157d11" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c5c909f-8e84-4edb-a6b7-ae477a157d11")) {                    Plotly.newPlot(                        "4c5c909f-8e84-4edb-a6b7-ae477a157d11",                        [{"hovertemplate":"year=%{x}\u003cbr\u003ey=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"black","dash":"solid","width":2},"marker":{"symbol":"circle","color":"purple","size":8},"mode":"lines+markers","name":"","orientation":"v","showlegend":false,"x":[2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020,2021,2022,2023,2024,2025],"xaxis":"x","y":[5664.09,6504.281999999999,6552.889499999999,6924.375,7134.5345,6147.85,5971.1065,6513.7845,6946.3345,6820.958500000001,6433.0895,7054.6355,7630.916,7979.798000000001,7979.798000000001,7979.798000000001],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":" ...

# %% [markdown]
# `GDP growth`

# %%
GDR = data.groupby('continent')['GDP Growth (% Annual)'].mean().round(2)
print(f'GDP growth per continent:\n{GDR}')

# Visualization

fig = px.bar(GDR,x=GDR.index,y=GDR.values,color=GDR.index,color_discrete_sequence=px.colors.sequential.Inferno,
    title='GDP growth by continent',
    hover_name=GDR.index,hover_data=['GDP Growth (% Annual)'])

fig.update_layout(width=1000,
    height=600,
    xaxis_title='Country',
    yaxis_title='GDP Growth (% Annual)')


fig.show()

fig.write_html("fig7_chart.html")
# Out:
# GDP growth per continent:
# continent
# Africa     5.85
# America    5.34
# Asia       5.94
# Europe     4.94
# Oceania    4.84
# Name: GDP Growth (% Annual), dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="99d0cb54-1a58-409d-b087-5cfd79f44d71" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("99d0cb54-1a58-409d-b087-5cfd79f44d71")) {                    Plotly.newPlot(                        "99d0cb54-1a58-409d-b087-5cfd79f44d71",                        [{"alignmentgroup":"True","customdata":[[5.85]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP Growth (% Annual)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Africa"],"legendgroup":"Africa","marker":{"color":"#000004","pattern":{"shape":""}},"name":"Africa","offsetgroup":"Africa","orientation":"v","showlegend":true,"textposition":"auto","x":["Africa"],"xaxis":"x","y":[5.85],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[5.34]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP Growth (% Annual)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["America"],"legendgroup":"America","marker":{"color":"#1b0c41","pattern":{"shape":""}},"name":"America","offsetgroup":"America","orientation":"v","showlegend":true,"textposition":"auto","x":["America"],"xaxis":"x","y":[5.34],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[5.94]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP Growth (% Annual)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Asia"],"legendgroup":"Asia","marker":{"color":"#4a0c6b","pattern":{"shape":""}},"name":"Asia","offsetgroup":"Asia","orientation":"v","showlegend":true,"textposition":"auto","x":["Asia"],"xaxis":"x","y":[5.94],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4.94]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP Growth (% Annual)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Europe"],"legendgroup":"Europe","marker":{"color":"#781c6d","pattern":{"shape":""}},"name":"Europe","offsetgroup":"Europe","orientation":"v","showlegend":true,"textposition":"auto","x":["Europe"],"xaxis":"x","y":[4.94],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[4.84]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003econtinent=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eGDP Growth (% Annual)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Oceania"],"legendgroup":"Oceania","marker":{"color":"#a52c60","pattern":{"shape":""}},"name":"Oceania","offsetgroup":"Oceania","orientation":"v","showlegend":true,"textposition":"auto","x":["Oceania"],"xaxis":"x","y":[4.84],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.777777777 ...

# %% [markdown]
# `Gross domestic product (GDP) vs Gross National Income (USD)`

# %%
corr = data['GDP (Current USD)'].corr(data['Gross National Income (USD)'])
print(f'Gross Domestic Product (GDP) and Gross National Income (USD) correlation : {corr}')
print()

# Visualization

fig = px.scatter(data, x='GDP (Current USD)',y="Gross National Income (USD)",
                 log_x=True,log_y=True,title="Gross domestic product (GDP) vs Gross National Income (USD)",
                  trendline='ols',hover_name='country_name')

fig.update_traces(marker=dict(size=12, color='purple'), selector=dict(mode='markers'))
fig.update_traces(line=dict(color='black', width=3), selector=dict(mode='lines'))

fig.update_layout(width=1000,
    height=600,
    xaxis_title='Gross domestic product (GDP)',
    yaxis_title='Gross National Income (USD)')


fig.show()

fig.write_html("fig8_chart.html")
# Out:
# Gross Domestic Product (GDP) and Gross National Income (USD) correlation : 0.9968499617365268
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="904a3b76-74f3-491f-b0e6-4325bdebcadd" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("904a3b76-74f3-491f-b0e6-4325bdebcadd")) {                    Plotly.newPlot(                        "904a3b76-74f3-491f-b0e6-4325bdebcadd",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eGDP (Current USD)=%{x}\u003cbr\u003eGross National Income (USD)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","B ...

# %% [markdown]
# `Inflation (GDP Deflator%) vs Unemployment Rate (%)`

# %%
corr = data['Inflation (GDP Deflator, %)'].corr(data['Unemployment Rate (%)'])
print(f'Inflation (GDP Deflator, %) and Unemployment Rate (%) correlaion : {corr}')
print()

# Visualization

fig = px.scatter(data,x="Inflation (GDP Deflator, %)",y='Unemployment Rate (%)',
                 title="Inflation (GDP Deflator%) vs Unemployment Rate (%)",
                  trendline='ols',hover_name="country_name")

fig.update_traces(marker=dict(size=12, color='darkblue'), selector=dict(mode='markers'))
fig.update_traces(line=dict(color='black', width=3), selector=dict(mode='lines'))

fig.update_layout(width=1000,height=600,xaxis_title='Inflation (GDP Deflator%)',yaxis_title='Unemployment Rate (%)')


fig.show()

fig.write_html("fig9_chart.html")
# Out:
# Inflation (GDP Deflator, %) and Unemployment Rate (%) correlaion : 0.021173473638900778
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e010dff2-9051-473e-b583-0a829327b3c2" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e010dff2-9051-473e-b583-0a829327b3c2")) {                    Plotly.newPlot(                        "e010dff2-9051-473e-b583-0a829327b3c2",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eInflation (GDP Deflator, %)=%{x}\u003cbr\u003eUnemployment Rate (%)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados ...

# %% [markdown]
# ` Inflation rates over the world `

# %%
infgr = data.groupby('country_name')['Inflation (GDP Deflator, %)'].median().sort_values(ascending=False).head(10)
print(f'Inflation rate per country:\n {infgr}')
print()

# Visualizaion

fig = px.bar(infgr,x=infgr.index,y=infgr.values,color=infgr.index,
             color_discrete_sequence=px.colors.sequential.Inferno,
             title='Hiehest inflation rates in the world',hover_name=infgr.index,hover_data=['Inflation (GDP Deflator, %)'])

fig.update_layout(width=1000,
    height=600,
    xaxis_title='Country',
    yaxis_title='Inflation (GDP Deflator, %)')


fig.show()

fig.write_html("fig10_chart.html")
# Out:
# Inflation rate per country:
#  country_name
# Sudan                   34.3445
# Argentina               33.3315
# Syrian Arab Republic    29.0080
# Iran, Islamic Rep.      24.7235
# Yemen, Rep.             16.4840
# Angola                  15.6655
# Ukraine                 14.7905
# Uzbekistan              13.8590
# Ghana                   13.5840
# Malawi                  13.0585
# Name: Inflation (GDP Deflator, %), dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="78ef89c0-4eca-478b-9775-5fde51a665a6" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("78ef89c0-4eca-478b-9775-5fde51a665a6")) {                    Plotly.newPlot(                        "78ef89c0-4eca-478b-9775-5fde51a665a6",                        [{"alignmentgroup":"True","customdata":[[34.3445]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eInflation (GDP Deflator, %)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Sudan"],"legendgroup":"Sudan","marker":{"color":"#000004","pattern":{"shape":""}},"name":"Sudan","offsetgroup":"Sudan","orientation":"v","showlegend":true,"textposition":"auto","x":["Sudan"],"xaxis":"x","y":[34.3445],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[33.3315]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eInflation (GDP Deflator, %)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Argentina"],"legendgroup":"Argentina","marker":{"color":"#1b0c41","pattern":{"shape":""}},"name":"Argentina","offsetgroup":"Argentina","orientation":"v","showlegend":true,"textposition":"auto","x":["Argentina"],"xaxis":"x","y":[33.3315],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[29.008]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eInflation (GDP Deflator, %)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Syrian Arab Republic"],"legendgroup":"Syrian Arab Republic","marker":{"color":"#4a0c6b","pattern":{"shape":""}},"name":"Syrian Arab Republic","offsetgroup":"Syrian Arab Republic","orientation":"v","showlegend":true,"textposition":"auto","x":["Syrian Arab Republic"],"xaxis":"x","y":[29.008],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[24.7235]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eInflation (GDP Deflator, %)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Iran, Islamic Rep."],"legendgroup":"Iran, Islamic Rep.","marker":{"color":"#781c6d","pattern":{"shape":""}},"name":"Iran, Islamic Rep.","offsetgroup":"Iran, Islamic Rep.","orientation":"v","showlegend":true,"textposition":"auto","x":["Iran, Islamic Rep."],"xaxis":"x","y":[24.7235],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[16.484]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eInflation (GDP Deflator, %)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Yemen, Rep."],"legendgroup":"Yemen, Rep.","marker":{"color":"#a52c60","pattern":{"shape":""}},"name":"Yemen, Rep.","offsetgroup":"Yemen, Rep.","orientation":"v","showlegend":true,"textposition":"auto","x":["Yemen, Rep."],"xaxis":"x","y":[16.484],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","customdata":[[15.665500000000002]],"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003ecountry_name=%{x}\u003cbr\u003ey=%{y}\u003cbr\u003eInflation (GDP Deflator, %)=%{customdata[0]}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Angola"],"legendgroup":"Angola","marker":{"color":"#cf4446","pattern":{"shape":""}},"name":"Angola","offsetgroup":"Angola","orientation":"v","showlegend":true,"textposition":"auto","x":["Angola"],"xaxis":"x","y":[15.665500000000002],"yaxis":"y","type":"bar"},{"alignmentgroup":"True ...

# %% [markdown]
# Due to political and economic instability, and wars, countries like Syria, Sudan, Iran, Yemen, and Ukraine experienced a high inflation rate

# %% [markdown]
# `fiscal balance % GDP' vs 'Current Account Balance (% GDP)`

# %%
corr = data['fiscal balance % GDP'].corr(data['Current Account Balance (% GDP)'])
print(f'fiscal balance and Current Account Balance correlaion : {corr}')
print()

# Visualization

fig = px.scatter(data,x="fiscal balance % GDP",y='Current Account Balance (% GDP)',
                 title="Fiscal balance % GDP vs Current Account Balance (% GDP)",
                  trendline='ols',hover_name="country_name")

fig.update_traces(marker=dict(size=12, color='darkred'), selector=dict(mode='markers'))
fig.update_traces(line=dict(color='black', width=3), selector=dict(mode='lines'))

fig.update_layout(width=1000,height=600,xaxis_title='Fiscal balance % GDP',yaxis_title='Current Account Balance (% GDP)')


fig.show()

fig.write_html("fig11_chart.html")
# Out:
# fiscal balance and Current Account Balance correlaion : 0.5735058002413743
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f08f66b7-5613-4b60-bb9f-207924cfa537" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f08f66b7-5613-4b60-bb9f-207924cfa537")) {                    Plotly.newPlot(                        "f08f66b7-5613-4b60-bb9f-207924cfa537",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003efiscal balance % GDP=%{x}\u003cbr\u003eCurrent Account Balance (% GDP)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barba ...

# %% [markdown]
# `Who runs surplus and who runs deficit`

# %%
df = data.groupby('country_name')['fiscal balance % GDP'].median()
total = len(df)
deficit = (df<0).sum()
surplus = (df>0).sum()
labels = ['Deficit', 'Surplus']
sizes = [deficit,surplus]

# Visualization

fig = px.pie(df,values=sizes,names=labels, title="Fiscal balance status",
             color_discrete_sequence=px.colors.sequential.Inferno)
fig.update_layout( width=500,
    height=500)

fig.show()
fig.write_html("fig12_chart.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1942a0e5-2f08-46c0-8e6b-9cc1ae66cac1" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1942a0e5-2f08-46c0-8e6b-9cc1ae66cac1")) {                    Plotly.newPlot(                        "1942a0e5-2f08-46c0-8e6b-9cc1ae66cac1",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"label=%{label}\u003cbr\u003evalue=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Deficit","Surplus"],"legendgroup":"","name":"","showlegend":true,"values":[146,66],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{ ...

# %% [markdown]
# `Givernment revenue and expense`

# %%
GE = data.groupby('subregion')[['Government Revenue (% of GDP)', 'Government Expense (% of GDP)']].mean().round(2).reset_index()
# Visualization
fig = px.bar(GE,x='subregion',y=['Government Revenue (% of GDP)', 'Government Expense (% of GDP)'],barmode='group',
             color_discrete_sequence=px.colors.sequential.Inferno,
    title='Average Government Revenue and Expense by Subregion')

fig.update_layout(width=1000,height=600,xaxis_title='Subregion',
                  yaxis_title='Average Government Revenue and Expense % GDP',xaxis_tickangle=45)

fig.show()

fig.write_html("fig13_chart.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d024bab4-0df7-49c0-a9c7-ccdfccbc7718" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d024bab4-0df7-49c0-a9c7-ccdfccbc7718")) {                    Plotly.newPlot(                        "d024bab4-0df7-49c0-a9c7-ccdfccbc7718",                        [{"alignmentgroup":"True","hovertemplate":"variable=Government Revenue (% of GDP)\u003cbr\u003esubregion=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Government Revenue (% of GDP)","marker":{"color":"#000004","pattern":{"shape":""}},"name":"Government Revenue (% of GDP)","offsetgroup":"Government Revenue (% of GDP)","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia and New Zealand","Caribbean","Central America","Central Asia","Eastern Africa","Eastern Asia","Eastern Europe","Melanesia","Micronesia","Middle Africa","Northern Africa","Northern America","Northern Europe","Polynesia","South America","South-eastern Asia","Southern Africa","Southern Asia","Southern Europe","Western Africa","Western Asia","Western Europe"],"xaxis":"x","y":[28.76,23.02,18.75,20.41,15.37,26.37,32.31,23.44,40.31,19.07,23.03,18.01,34.57,39.42,24.0,25.67,32.14,13.97,36.27,15.65,27.08,37.45],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"variable=Government Expense (% of GDP)\u003cbr\u003esubregion=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Government Expense (% of GDP)","marker":{"color":"#1b0c41","pattern":{"shape":""}},"name":"Government Expense (% of GDP)","offsetgroup":"Government Expense (% of GDP)","orientation":"v","showlegend":true,"textposition":"auto","x":["Australia and New Zealand","Caribbean","Central America","Central Asia","Eastern Africa","Eastern Asia","Eastern Europe","Melanesia","Micronesia","Middle Africa","Northern Africa","Northern America","Northern Europe","Polynesia","South America","South-eastern Asia","Southern Africa","Southern Asia","Southern Europe","Western Africa","Western Asia","Western Europe"],"xaxis":"x","y":[30.22,24.35,19.73,17.47,16.78,21.54,35.05,25.7,53.56,12.39,25.29,21.7,35.72,42.33,26.83,18.56,33.21,18.69,39.09,15.79,27.27,38.88],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8 ...

# %% [markdown]
# `Government revenue vs Tax revenue`

# %%
corr = data['Government Revenue (% of GDP)'].corr(data['Tax Revenue (% of GDP)'])
print(f'Government Revenue (% of GDP) and Tax Revenue (% of GDP)correlation : {corr}')
print()

# Visualization

fig = px.scatter(data,x="Tax Revenue (% of GDP)",y='Government Revenue (% of GDP)',
                 title="Government Revenue (% of GDP) vs Tax Revenue (% of GDP)",
                  trendline='ols',hover_name="country_name")

fig.update_traces(marker=dict(size=12, color='navy'), selector=dict(mode='markers'))
fig.update_traces(line=dict(color='black', width=3), selector=dict(mode='lines'))

fig.update_layout(width=1000,
    height=600,
    xaxis_title='Tax Revenue (% of GDP)',
    yaxis_title='Government Revenue (% of GDP)')

fig.show()

fig.write_html("fig14_chart.html")
# Out:
# Government Revenue (% of GDP) and Tax Revenue (% of GDP)correlation : 0.7464766196255339
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b215a6a4-7fb7-494e-bf13-168cf94afe11" class="plotly-graph-div" style="height:600px; width:1000px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b215a6a4-7fb7-494e-bf13-168cf94afe11")) {                    Plotly.newPlot(                        "b215a6a4-7fb7-494e-bf13-168cf94afe11",                        [{"hovertemplate":"\u003cb\u003e%{hovertext}\u003c\u002fb\u003e\u003cbr\u003e\u003cbr\u003eTax Revenue (% of GDP)=%{x}\u003cbr\u003eGovernment Revenue (% of GDP)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","hovertext":["Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","Andorra","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","United Arab Emirates","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Afghanistan","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Antigua and Barbuda","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Albania","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Armenia","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Angola","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","Argentina","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","American Samoa","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Austria","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Australia","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Aruba","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Azerbaijan","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Bosnia and Herzegovina","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barbados","Barba ...

# %% [markdown]
# # Insights

# %% [markdown]
# *   Global GDP and GDP per capita have steadily increased over the past 15 years, indicating overall economic growth and improving average income levels worldwide.
#
# *   Asia and Europe together account for more than 75% of the global economy, making them the dominant players in global output.
#
# *   Asian and African markets are growing faster than the U.S. and Europe. This is typical, as emerging markets tend to achieve higher growth rates compared to more mature economies.
#
# *   There is a strong positive relationship between GDP and GNI — as economic output increases, national income tends to rise as well.
#
#
# *   High inflation in many countries is often linked to wars and political instability, which disrupt economic activity and drive prices up.
#
#
# *   There appears to be little to no clear relationship between inflation and unemployment in the data, suggesting the connection is not consistent across countries.
#
# *   Fiscal balance and current account balance show a strong positive correlation, meaning countries tend to run similar patterns in both.
#
# *   Most countries operate with fiscal deficits. The key issue is not the deficit itself, but its size and how it is financed.
#
# *   Tax revenue is strongly correlated with government revenue, as it represents a major source of income for governments.
